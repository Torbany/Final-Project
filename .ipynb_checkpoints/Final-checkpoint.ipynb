# %% [markdown]
# # Final_MLOPS

# %% [markdown]
# # Fraud Detection System

# %% [markdown]
# #### Saeed Ahmed, Amr Amer, Dima Yasser, Ahmed abdelmalek, Abdelrahman said

# %% [markdown]
# ### Step 1 Dataset Loading and Preprocessing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, f1_score
from imblearn.over_sampling import SMOTE
import pickle
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('creditcard.csv')

# Get basic information about the dataset
print("Dataset Information:")
print(data.info())

print("\nFirst few rows of the dataset:")
print(data.head())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %% [markdown]
# ### Step 2: Data Splitting

# %%
# Split data into features and labels
X = data.drop('Class', axis=1)
y = data['Class']

# Handle class imbalance
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Step 3: Transactions Exploratory Data Analysis

# %%
# Extract fraudulent transactions
fraudulent_transactions = data[data['Class'] == 1].head(5)  # Extract first 5 fraudulent transactions
fraudulent_transactions_list = fraudulent_transactions.drop('Class', axis=1).values.tolist()

print(fraudulent_transactions_list)
# Out:
# [[406.0, -2.3122265423263, 1.95199201064158, -1.60985073229769, 3.9979055875468, -0.522187864667764, -1.42654531920595, -2.53738730624579, 1.39165724829804, -2.77008927719433, -2.77227214465915, 3.20203320709635, -2.89990738849473, -0.595221881324605, -4.28925378244217, 0.389724120274487, -1.14074717980657, -2.83005567450437, -0.0168224681808257, 0.416955705037907, 0.126910559061474, 0.517232370861764, -0.0350493686052974, -0.465211076182388, 0.320198198514526, 0.0445191674731724, 0.177839798284401, 0.261145002567677, -0.143275874698919, 0.0], [472.0, -3.0435406239976, -3.15730712090228, 1.08846277997285, 2.2886436183814, 1.35980512966107, -1.06482252298131, 0.325574266158614, -0.0677936531906277, -0.270952836226548, -0.838586564582682, -0.414575448285725, -0.503140859566824, 0.676501544635863, -1.69202893305906, 2.00063483909015, 0.666779695901966, 0.599717413841732, 1.72532100745514, 0.283344830149495, 2.10233879259444, 0.661695924845707, 0.435477208966341, 1.37596574254306, -0.293
# ...

# %%
import seaborn as sns
# Separate fraudulent and non-fraudulent transactions
fraud = data[data['Class'] == 1]
non_fraud = data[data['Class'] == 0]

# Display basic statistics for fraudulent transactions
print("Fraudulent transactions statistics:")
print(fraud.describe())

# Display the number of fraudulent transactions
print("Number of fraudulent transactions:", len(fraud))
print("Number of non-fraudulent transactions:", len(non_fraud))

# Visualizing a Few Features
plt.figure(figsize=(14, 10))
for i, column in enumerate(data.columns[:10], 1):
    plt.subplot(5, 2, i)
    sns.histplot(data[column][data['Class'] == 1], color='red', kde=True, label='Fraud')
    sns.histplot(data[column][data['Class'] == 0], color='blue', kde=True, label='Non-Fraud')
    plt.title(f'Distribution of {column}')
    plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Fraudulent transactions statistics:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %% [markdown]
# ### Step 4: Model Trainning & Evaluation

# %%
# Train a Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy)
print("Precision:", precision)
print("F1 Score:", f1)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56750
#            1       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
# Accuracy: 0.999903276295658
# Precision: 0.9998069735202766
# F1 Score: 0.9999034774444338

# %% [markdown]
# ### Step 5: Model Saving

# %%
# Save the model and scaler
with open('models/model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)
with open('models/scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

# Save the metrics
metrics = {'accuracy': accuracy, 'precision': precision, 'f1': f1}
with open('models/metrics.pkl', 'wb') as metrics_file:
    pickle.dump(metrics, metrics_file)

# %% [markdown]
# ### Step 6: Visualizing Metrics

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, f1_score
# Visualizing Metrics

metrics_names = ['Accuracy', 'Precision', 'F1 Score']
metrics_values = [metrics['accuracy'], metrics['precision'], metrics['f1']]

plt.figure(figsize=(8, 6))
plt.bar(metrics_names, metrics_values, color=['blue', 'green', 'red'])
plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.title('Model Evaluation Metrics')
plt.ylim(0, 1)

# Add text labels on bars
for i, value in enumerate(metrics_values):
    plt.text(i, value + 0.01, f'{value:.2f}', ha='center', va='bottom')

plt.show()
